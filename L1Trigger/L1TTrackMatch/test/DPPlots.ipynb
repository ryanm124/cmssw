# %%
import matplotlib.pyplot as plt  # matplotlib library
import mplhep as hep  # HEP (CMS) extensions/styling on top of mpl

# For constructing examples
import hist  # histogramming library
import numpy as np

# %%
pt_primary_quality_eff = np.array([0.766277, 0.789011, 0.835206, 0.883080, 0.918110, 0.933530, 0.942691, 0.949153, 0.953990, 0.957326, 0.958858, 0.960171, 0.963565, 0.963980, 0.961050, 0.948938, 0.944354, 0.936228, 0.918200, 0.776389])
pt_primary_quality_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_primary_quality_err = np.array([0.017291, 0.013525, 0.010154, 0.007618, 0.005441, 0.004282, 0.003540, 0.002982, 0.002657, 0.002469, 0.002362, 0.002375, 0.002390, 0.002629, 0.003250, 0.004679, 0.006558, 0.009001, 0.012393, 0.015528])
pt_primary_quality_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_primary_minpt_eff = np.array([0.000000, 0.000000, 0.788015, 0.883080, 0.918110, 0.933530, 0.942691, 0.949153, 0.953990, 0.957326, 0.958858, 0.960171, 0.963565, 0.963980, 0.961050, 0.948938, 0.944354, 0.936228, 0.918200, 0.776389])
pt_primary_minpt_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_primary_minpt_err = np.array([0.000000, 0.000000, 0.011186, 0.007618, 0.005441, 0.004282, 0.003540, 0.002982, 0.002657, 0.002469, 0.002362, 0.002375, 0.002390, 0.002629, 0.003250, 0.004679, 0.006558, 0.009001, 0.012393, 0.015528])
pt_primary_minpt_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_primary_mind0_eff = np.array([0.000000, 0.000000, 0.640449, 0.727937, 0.721260, 0.745052, 0.726218, 0.747973, 0.718468, 0.726798, 0.717093, 0.698776, 0.707547, 0.687761, 0.638160, 0.636240, 0.633388, 0.624152, 0.611452, 0.561111])
pt_primary_mind0_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_primary_mind0_err = np.array([0.000000, 0.000000, 0.013134, 0.010551, 0.008897, 0.007491, 0.006792, 0.005893, 0.005704, 0.005443, 0.005356, 0.005572, 0.005801, 0.006537, 0.008073, 0.010227, 0.013785, 0.017841, 0.022042, 0.018494])
pt_primary_mind0_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
f, ax = plt.subplots()
plt.errorbar(pt_primary_quality_center, pt_primary_quality_eff, xerr=pt_primary_quality_widths/2, yerr=pt_primary_quality_err, marker=".", linestyle="", markersize=15,label="Quality")
plt.errorbar(pt_primary_minpt_center, pt_primary_minpt_eff, xerr=pt_primary_minpt_widths/2, yerr=pt_primary_minpt_err, marker="v", linestyle="", markersize=8,label="$p_T$ min")
plt.errorbar(pt_primary_mind0_center, pt_primary_mind0_eff, xerr=pt_primary_mind0_widths/2, yerr=pt_primary_mind0_err, marker="s", linestyle="", markersize=8,label="$d_0$ min")
plt.ylim(0.0, 1.2)
plt.xlim(0.0,100.0)
plt.xlabel("Track $p_{T}$ [GeV]")
plt.ylabel("Efficiency")
plt.text(0.2,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
plt.legend()
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
#plt.savefig(save_dir + save_name + ".pdf", bbox_inches="tight")
#plt.savefig(save_dir + save_name + ".png", bbox_inches="tight")
#plt.close()
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
pt_np_quality_eff = np.array([0.800058, 0.767310, 0.696188, 0.599612, 0.487104, 0.378729, 0.287805, 0.225143, 0.173625, 0.148224, 0.125820, 0.113522, 0.103407, 0.091833, 0.089870, 0.080458, 0.074586, 0.058870, 0.049633, 0.032580])
pt_np_quality_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_np_quality_err = np.array([0.000288, 0.000403, 0.000562, 0.000778, 0.001001, 0.001191, 0.001321, 0.001409, 0.001461, 0.001543, 0.001599, 0.001714, 0.001825, 0.001907, 0.002115, 0.002201, 0.002368, 0.002335, 0.002381, 0.000924])
pt_np_quality_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_np_minpt_eff = np.array([0.000000, 0.000000, 0.627665, 0.599612, 0.487104, 0.378729, 0.287805, 0.225143, 0.173625, 0.148224, 0.125820, 0.113522, 0.103407, 0.091833, 0.089870, 0.080458, 0.074586, 0.058870, 0.049633, 0.032580])
pt_np_minpt_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_np_minpt_err = np.array([0.000000, 0.000000, 0.000590, 0.000778, 0.001001, 0.001191, 0.001321, 0.001409, 0.001461, 0.001543, 0.001599, 0.001714, 0.001825, 0.001907, 0.002115, 0.002201, 0.002368, 0.002335, 0.002381, 0.000924])
pt_np_minpt_center = np.array( [2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_np_mind0_eff = np.array([0.000000, 0.000000, 0.165813, 0.130809, 0.089980, 0.063575, 0.047448, 0.039769, 0.032214, 0.028314, 0.025066, 0.024877, 0.026175, 0.022511, 0.022686, 0.020622, 0.019012, 0.020083, 0.018387, 0.016995])
pt_np_mind0_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_np_mind0_err = np.array([0.000000, 0.000000, 0.000454, 0.000535, 0.000573, 0.000599, 0.000620, 0.000659, 0.000681, 0.000720, 0.000754, 0.000842, 0.000957, 0.000980, 0.001101, 0.001150, 0.001231, 0.001392, 0.001473, 0.000673])
pt_np_mind0_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
f, ax = plt.subplots()
plt.errorbar(pt_np_quality_center, pt_np_quality_eff, xerr=pt_np_quality_widths/2, yerr=pt_np_quality_err, marker=".", linestyle="", markersize=15,label="Quality")
plt.errorbar(pt_np_minpt_center, pt_np_minpt_eff, xerr=pt_np_minpt_widths/2, yerr=pt_np_minpt_err, marker="v", linestyle="", markersize=8,label="$p_T$ min")
plt.errorbar(pt_np_mind0_center, pt_np_mind0_eff, xerr=pt_np_mind0_widths/2, yerr=pt_np_mind0_err, marker="s", linestyle="", markersize=8,label="$d_0$ min")
plt.ylim(0.0, 1.2)
plt.xlim(0.0,100.0)
plt.xlabel("Track $p_{T}$ [GeV]")
plt.ylabel("Efficiency")
plt.text(0.2,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
plt.legend()
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
#plt.savefig(save_dir + save_name + ".pdf", bbox_inches="tight")
#plt.savefig(save_dir + save_name + ".png", bbox_inches="tight")
#plt.close()
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
pt = [0.11608079625861531, 0.15341422894206785, 0.202754688117867, 0.2679638247199172, 0.35414525811992303, 0.4680440129555473, 0.6185744212036046, 0.8175178059669256, 1.0804445514778123, 1.4279327254987262, 1.8871786300938118, 2.494125331176839, 3.2962757570589627, 4.356410534288525, 5.757501538704108, 7.609205722755407, 10.056447461105792, 13.290761115256025, 17.5652815475832]
pt_err = [0.016080796258615304, 0.021252636424837226, 0.02808782275096193, 0.037121313851088286, 0.04906011954891756, 0.06483863528670672, 0.0856917729613505, 0.11325161180197052, 0.14967513370891627, 0.19781304031199765, 0.2614328642830879, 0.3455138367999393, 0.4566365890821842, 0.603498188147378, 0.7975928162682058, 1.0541113677830922, 1.3931303705672935, 1.8411832835829394, 2.4333371487442363]
eff = [0.01913876,0.03870968,0.05444126,0.05932203,0.09871795,0.09688995,0.13048369,0.14241164,0.12814371,0.1352075,0.16916168,0.20887246,0.14470842,0.13429257,0.11683849,0.05607477,0.15463918,0.16541353,0.22424242]
faker = [0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,0.000000e+00,7.183392e-05]
err_eff = [0.00670151,0.00774714,0.00858777,0.00887793,0.01068024,0.01023073,0.01129708,0.01126742,0.01156719,0.01251112,0.01450511,0.01747693,0.01634984,0.0166972,0.0188307,0.01572699,0.02595852,0.03221776,0.03246982]
err_faker = [0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,0.00000000e+00,7.18313399e-05]

# %%
f, ax = plt.subplots()
plt.errorbar(pt,eff,yerr=err_eff,xerr=pt_err,linestyle='None',fmt='o')
plt.xlabel('R$_{T}$ [cm]')
plt.ylabel('True Positive Rate')
plt.text(0.2,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
plt.text(0.27,0.85,r"Decision threshold > 0.99",transform=ax.transAxes,fontsize=17)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
f, ax = plt.subplots()
plt.errorbar(pt,faker,yerr=err_faker,xerr=pt_err,linestyle='None',fmt='o')
plt.xlabel('R$_{T}$ [cm]')
plt.ylabel('False Positive Rate')
plt.text(0.2,0.9,r"Neutrino Gun",transform=ax.transAxes)
plt.text(0.17,0.85,r"Decision threshold > 0.99",transform=ax.transAxes,fontsize=17)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
f, ax = plt.subplots()
darkphoton_trigEff = [0.999573,0.996314,0.993483,0.639476,0.593269,0.547329,0.530395,0.510096,0.477244,0.419818,0.0]
x = ["",f".02<$R_T$<20",f"$\Sigma q \leq $0",f"$\Sigma q \geq $0","score>0.8","score>0.9","score>0.95","score>0.96","score>0.97","score>0.98","score>0.99"]
arr = ax.hist(x,10, weights=darkphoton_trigEff,histtype="step")
plt.xticks(rotation=30, ha='right')
plt.ylim(0,1.1)
plt.ylabel('Percentage of Events Triggered')
plt.text(0.4,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
for i in range(10):
    plt.text(arr[1][i]+0.4,arr[0][i]+0.02,"{:5.3f}".format(arr[0][i]),rotation="vertical",fontsize=12)

# %%
f, ax = plt.subplots()
darkphoton_trigEff = [0.99235,0.972732,0.95499,0.00238812,0.00145716,0.0008635,0.000728578,0.000580164,0.000418258,0.000269844,0.0]
x = ["",f".02<$R_T$<20",f"$\Sigma q \leq $0",f"$\Sigma q \geq $0","score>0.8","score>0.9","score>0.95","score>0.96","score>0.97","score>0.98","score>0.99"]
arr = ax.hist(x,10, weights=darkphoton_trigEff,histtype="step")
plt.xticks(rotation=30, ha='right')
plt.ylim(0,1.1)
plt.ylabel('Percentage of Events Triggered')
plt.text(0.4,0.9,r"Neutrino Gun",transform=ax.transAxes)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
for i in range(10):
    if(i<3):
        plt.text(arr[1][i]+0.4,arr[0][i]+0.02,"{:5.3f}".format(arr[0][i]),rotation="vertical",fontsize=12)
    elif(i<5):
        plt.text(arr[1][i]+0.4,arr[0][i]+0.02,"{:7.5f}".format(arr[0][i]),rotation="vertical",fontsize=12)
    else:
        plt.text(arr[1][i]+0.4,arr[0][i]+0.02,"{:8.6f}".format(arr[0][i]),rotation="vertical",fontsize=12)

# %%
matchedVert_score = [0.025349, 0.015331, 0.011955, 0.010073, 0.008025, 0.007306, 0.006697, 0.005756, 0.005424, 0.004206, 0.005867, 0.004815, 0.005867, 0.005922, 0.005811, 0.005092, 0.005645, 0.004151, 0.004538, 0.004704, 0.004372, 0.004538, 0.005811, 0.004704, 0.005147, 0.005535, 0.005867, 0.004649, 0.005203, 0.005535, 0.005756, 0.005867, 0.005147, 0.005258, 0.006254, 0.006642, 0.007416, 0.007859, 0.007250, 0.009354, 0.009464, 0.011623, 0.013117, 0.017489, 0.018486, 0.022747, 0.030994, 0.040292, 0.076821, 0.488267]
unmatchedVert_score = [0.701890, 0.035404, 0.016657, 0.011217, 0.008488, 0.006809, 0.005585, 0.004827, 0.004029, 0.003775, 0.003433, 0.003304, 0.002854, 0.002795, 0.002585, 0.002426, 0.002439, 0.002192, 0.002288, 0.002095, 0.001965, 0.002020, 0.001964, 0.001878, 0.001884, 0.001924, 0.001854, 0.001915, 0.001914, 0.001841, 0.001935, 0.001932, 0.001954, 0.002037, 0.002138, 0.002289, 0.002236, 0.002495, 0.002518, 0.002746, 0.002964, 0.003251, 0.003592, 0.004217, 0.004855, 0.005879, 0.007720, 0.010951, 0.018454, 0.071583]

# %%
f, ax = plt.subplots()
bins = np.linspace(0,1,50)
ax.hist(bins,50, weights=matchedVert_score,histtype="step",color="black",label="matched")
ax.hist(bins,50, weights=unmatchedVert_score,histtype="step",color="red",label="unmatched")
plt.xlabel('Score')
plt.legend()
plt.ylabel('Normalized Counts')
plt.text(0.1,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
pt_baseline_eff = np.array([0.000000, 0.000000, 0.500000, 1.000000, 0.583333, 0.708333, 0.811594, 0.802469, 0.820253, 0.813065, 0.839597, 0.807692, 0.795156, 0.786931, 0.782371, 0.757607, 0.779528, 0.770898, 0.742105, 0.757848])
pt_baseline_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_baseline_err = np.array([0.000000, 0.000000, 0.353553, 0.000000, 0.142319, 0.065606, 0.033287, 0.019784, 0.011154, 0.008739, 0.007223, 0.007336, 0.007402, 0.008149, 0.010174, 0.013647, 0.018393, 0.023384, 0.031738, 0.028687])
pt_baseline_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_0p9_eff = np.array([0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.095359, 0.255779, 0.496319, 0.571726, 0.680457, 0.723564, 0.706383, 0.696755, 0.724409, 0.705882, 0.700000, 0.690583])
pt_0p9_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_0p9_err = np.array([0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.008532, 0.009780, 0.009842, 0.009211, 0.008552, 0.008900, 0.011229, 0.014639, 0.019824, 0.025353, 0.033245, 0.030955])
pt_0p9_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_0p95_eff = np.array([0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.043882, 0.176382, 0.399845, 0.483368, 0.624285, 0.699802, 0.686930, 0.671400, 0.708661, 0.681115, 0.684211, 0.659193])
pt_0p95_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_0p95_err = np.array([0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.005950, 0.008544, 0.009642, 0.009302, 0.008882, 0.009121, 0.011434, 0.014958, 0.020160, 0.025931, 0.033722, 0.031740])
pt_0p95_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_0p99_eff = np.array([0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.004219, 0.044724, 0.194886, 0.269924, 0.440296, 0.585347, 0.576900, 0.558824, 0.586614, 0.544892, 0.568421, 0.533632])
pt_0p99_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_0p99_err = np.array([0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.001883, 0.004633, 0.007797, 0.008263, 0.009104, 0.009804, 0.012181, 0.015813, 0.021849, 0.027708, 0.035933, 0.033407])
pt_0p99_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
f, ax = plt.subplots()
plt.errorbar(pt_baseline_center, pt_baseline_eff, xerr=pt_baseline_widths/2, yerr=pt_baseline_err, marker=".", linestyle="", markersize=15,label="Baseline")
plt.errorbar(pt_0p9_center, pt_0p9_eff, xerr=pt_0p9_widths/2, yerr=pt_0p9_err, marker="v", linestyle="", markersize=8,label="score>0.9")
plt.errorbar(pt_0p95_center, pt_0p95_eff, xerr=pt_0p95_widths/2, yerr=pt_0p95_err, marker="s", linestyle="", markersize=8,label="score>0.95")
plt.errorbar(pt_0p99_center, pt_0p99_eff, xerr=pt_0p99_widths/2, yerr=pt_0p99_err, marker="d", linestyle="", markersize=8,label="score>0.99")
plt.ylim(0.0, 1.2)
plt.xlim(0.0,100.0)
plt.xlabel("Vertex Tracking Particle $p_{T}$ [GeV]")
plt.ylabel("Efficiency")
plt.text(0.2,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
plt.legend()
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
R_T_baseline_eff = np.array([0.595855, 0.698718, 0.803758, 0.855244, 0.818182, 0.847341, 0.861687, 0.864494, 0.847931, 0.833245, 0.824444, 0.805658, 0.764131, 0.748696, 0.667107, 0.635185, 0.597938, 0.573864, 0.611111, 0.415094] )
R_T_baseline_widths = np.array([0.030332, 0.039533, 0.051524, 0.067152, 0.087520, 0.114067, 0.148666, 0.193760, 0.252531, 0.329129, 0.428961, 0.559074, 0.728654, 0.949670, 1.237725, 1.613153, 2.102457, 2.740177, 3.571331, 4.654593])
R_T_baseline_err = np.array([0.035323, 0.025975, 0.018146, 0.013523, 0.012540, 0.010533, 0.009079, 0.008184, 0.008324, 0.008604, 0.008967, 0.009813, 0.011215, 0.012791, 0.017128, 0.020715, 0.028743, 0.037275, 0.051387, 0.067683])
R_T_baseline_center = np.array([0.115166, 0.150098, 0.195626, 0.254964, 0.332300, 0.433094, 0.564461, 0.735673, 0.958819, 1.249649, 1.628694, 2.122712, 2.766576, 3.605738, 4.699435, 6.124874, 7.982679, 10.403996, 13.559750, 17.672711])

# %%
R_T_0p9_eff = np.array([0.067358, 0.108974, 0.215031, 0.307238, 0.327696, 0.435678, 0.479253, 0.531161, 0.601827, 0.635056, 0.657778, 0.662977, 0.639218, 0.663478, 0.601057, 0.572222, 0.539519, 0.517045, 0.588889, 0.358491])
plt.errorbar(R_T_baseline_center, R_T_baseline_eff, xerr=R_T_baseline_widths/2, yerr=R_T_baseline_err, marker=".", linestyle="", markersize=15,label="Baseline")
plt.errorbar(R_T_0p9_center, R_T_0p9_eff, xerr=R_T_0p9_widths/2, yerr=R_T_0p9_err, marker="v", linestyle="", markersize=8,label="score>0.9")
plt.errorbar(R_T_0p95_center, R_T_0p95_eff, xerr=R_T_0p95_widths/2, yerr=R_T_0p95_err, marker="s", linestyle="", markersize=8,label="score>0.95")
plt.errorbar(R_T_0p99_center, R_T_0p99_eff, xerr=R_T_0p99_widths/2, yerr=R_T_0p99_err, marker="d", linestyle="", markersize=8,label="score>0.99")
plt.ylim(0.0, 1.2)
plt.xlim(0.0,20.0)
plt.xlabel("Vertex $R_{T}$ [cm]")
plt.ylabel("Efficiency")
plt.text(0.2,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes)
plt.legend()
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
res_x = [1.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 2.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 2.000000, 0.000000, 2.000000, 4.000000, 1.000000, 0.000000, 3.000000, 5.000000, 2.000000, 2.000000, 5.000000, 7.000000, 8.000000, 21.000000, 26.000000, 30.000000, 58.000000, 111.000000, 259.000000, 710.000000, 1918.000000, 1924.000000, 634.000000, 257.000000, 122.000000, 57.000000, 50.000000, 33.000000, 24.000000, 9.000000, 14.000000, 8.000000, 12.000000, 3.000000, 5.000000, 3.000000, 4.000000, 4.000000, 3.000000, 0.000000, 2.000000, 2.000000, 0.000000, 2.000000, 1.000000, 0.000000, 3.000000, 1.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 2.000000, 0.000000, 0.000000, 0.000000, 0.000000, 2.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000]
fit = [0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000009, 0.001102, 0.065976, 1.989635, 30.221160, 231.204709, 890.902213, 1729.064600, 1690.208258, 832.179548, 206.367677, 25.775917, 1.621565, 0.051381, 0.000820, 0.000007, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000]
binCenters = [-0.990000, -0.970000, -0.950000, -0.930000, -0.910000, -0.890000, -0.870000, -0.850000, -0.830000, -0.810000, -0.790000, -0.770000, -0.750000, -0.730000, -0.710000, -0.690000, -0.670000, -0.650000, -0.630000, -0.610000, -0.590000, -0.570000, -0.550000, -0.530000, -0.510000, -0.490000, -0.470000, -0.450000, -0.430000, -0.410000, -0.390000, -0.370000, -0.350000, -0.330000, -0.310000, -0.290000, -0.270000, -0.250000, -0.230000, -0.210000, -0.190000, -0.170000, -0.150000, -0.130000, -0.110000, -0.090000, -0.070000, -0.050000, -0.030000, -0.010000, 0.010000, 0.030000, 0.050000, 0.070000, 0.090000, 0.110000, 0.130000, 0.150000, 0.170000, 0.190000, 0.210000, 0.230000, 0.250000, 0.270000, 0.290000, 0.310000, 0.330000, 0.350000, 0.370000, 0.390000, 0.410000, 0.430000, 0.450000, 0.470000, 0.490000, 0.510000, 0.530000, 0.550000, 0.570000, 0.590000, 0.610000, 0.630000, 0.650000, 0.670000, 0.690000, 0.710000, 0.730000, 0.750000, 0.770000, 0.790000, 0.810000, 0.830000, 0.850000, 0.870000, 0.890000, 0.910000, 0.930000, 0.950000, 0.970000, 0.990000]

# %%
f, ax = plt.subplots()
bins = np.linspace(-1,1,100)
ax.hist(bins,100, weights=res_x,histtype="step")
ax.plot(binCenters,fit)
plt.xlabel('X Position Residual [cm]')
plt.ylabel('Counts')
plt.text(0.05,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes,fontsize=20)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
plt.text(0.12,0.85,"RMS = 0.0242 cm",transform=ax.transAxes,fontsize=17)
# Out:
# Text(0.12, 0.85, 'RMS = 0.0242 cm')

# %%
res_y = [0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 2.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 2.000000, 1.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 2.000000, 2.000000, 1.000000, 2.000000, 0.000000, 3.000000, 2.000000, 8.000000, 3.000000, 10.000000, 18.000000, 21.000000, 31.000000, 33.000000, 67.000000, 106.000000, 221.000000, 682.000000, 1984.000000, 1902.000000, 693.000000, 244.000000, 112.000000, 63.000000, 39.000000, 29.000000, 15.000000, 8.000000, 8.000000, 6.000000, 9.000000, 1.000000, 2.000000, 2.000000, 3.000000, 1.000000, 2.000000, 4.000000, 2.000000, 2.000000, 2.000000, 0.000000, 1.000000, 1.000000, 2.000000, 0.000000, 1.000000, 0.000000, 0.000000, 1.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 2.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 2.000000]
fit = [0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000002, 0.000381, 0.030501, 1.176381, 21.873366, 196.072655, 847.329201, 1765.310284, 1773.060940, 858.538958, 200.414936, 22.554536, 1.223690, 0.032007, 0.000404, 0.000002, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000]
binCenters = [-0.990000, -0.970000, -0.950000, -0.930000, -0.910000, -0.890000, -0.870000, -0.850000, -0.830000, -0.810000, -0.790000, -0.770000, -0.750000, -0.730000, -0.710000, -0.690000, -0.670000, -0.650000, -0.630000, -0.610000, -0.590000, -0.570000, -0.550000, -0.530000, -0.510000, -0.490000, -0.470000, -0.450000, -0.430000, -0.410000, -0.390000, -0.370000, -0.350000, -0.330000, -0.310000, -0.290000, -0.270000, -0.250000, -0.230000, -0.210000, -0.190000, -0.170000, -0.150000, -0.130000, -0.110000, -0.090000, -0.070000, -0.050000, -0.030000, -0.010000, 0.010000, 0.030000, 0.050000, 0.070000, 0.090000, 0.110000, 0.130000, 0.150000, 0.170000, 0.190000, 0.210000, 0.230000, 0.250000, 0.270000, 0.290000, 0.310000, 0.330000, 0.350000, 0.370000, 0.390000, 0.410000, 0.430000, 0.450000, 0.470000, 0.490000, 0.510000, 0.530000, 0.550000, 0.570000, 0.590000, 0.610000, 0.630000, 0.650000, 0.670000, 0.690000, 0.710000, 0.730000, 0.750000, 0.770000, 0.790000, 0.810000, 0.830000, 0.850000, 0.870000, 0.890000, 0.910000, 0.930000, 0.950000, 0.970000, 0.990000]

# %%
f, ax = plt.subplots()
bins = np.linspace(-1,1,100)
ax.hist(bins,100, weights=res_y,histtype="step")
ax.plot(binCenters,fit)
plt.xlabel('Y Position Residual [cm]')
plt.ylabel('Counts')
plt.text(0.05,0.9,r"Dark Photon, c$\tau$=10mm",transform=ax.transAxes,fontsize=20)
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
plt.text(0.12,0.85,"RMS = 0.0234 cm",transform=ax.transAxes,fontsize=17)
# Out:
# Text(0.12, 0.85, 'RMS = 0.0234 cm')

# %%
res_z = [1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000, 1.000000, 0.000000, 1.000000, 0.000000, 1.000000, 0.000000, 0.000000, 0.000000,
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
plt.text(0.12,0.85,"RMS = 0.5682 cm",transform=ax.transAxes,fontsize=17)
# Out:
# Text(0.12, 0.85, 'RMS = 0.5682 cm')

# %%
pt_np_quality_eff = np.array([0.809767, 0.780912, 0.711717, 0.613023, 0.496376, 0.371869, 0.262398, 0.178951, 0.116261, 0.076023, 0.048437, 0.032213, 0.022228, 0.015937, 0.012491, 0.009522, 0.007825, 0.007847, 0.006129, 0.005633])
pt_np_quality_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_np_quality_err = np.array([0.000146, 0.000206, 0.000293, 0.000414, 0.000546, 0.000657, 0.000722, 0.000737, 0.000708, 0.000660, 0.000599, 0.000552, 0.000511, 0.000479, 0.000474, 0.000451, 0.000457, 0.000501, 0.000486, 0.000217])
pt_np_quality_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_np_minpt_eff = np.array([0.000000, 0.000000, 0.641399, 0.613023, 0.496376, 0.371869, 0.262398, 0.178951, 0.116261, 0.076023, 0.048437, 0.032213, 0.022228, 0.015937, 0.012491, 0.009522, 0.007825, 0.007847, 0.006129, 0.005633])
pt_np_minpt_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_np_minpt_err = np.array([0.000000, 0.000000, 0.000310, 0.000414, 0.000546, 0.000657, 0.000722, 0.000737, 0.000708, 0.000660, 0.000599, 0.000552, 0.000511, 0.000479, 0.000474, 0.000451, 0.000457, 0.000501, 0.000486, 0.000217])
pt_np_minpt_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_np_mind0_eff = np.array([0.000000, 0.000000, 0.168015, 0.130868, 0.088449, 0.057370, 0.038024, 0.025502, 0.016955, 0.012141, 0.009974, 0.007977, 0.007417, 0.006682, 0.006246, 0.005916, 0.005620, 0.005780, 0.004965, 0.005112])
pt_np_mind0_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_np_mind0_err = np.array([0.000000, 0.000000, 0.000242, 0.000287, 0.000310, 0.000316, 0.000314, 0.000303, 0.000285, 0.000273, 0.000277, 0.000278, 0.000297, 0.000312, 0.000336, 0.000356, 0.000388, 0.000431, 0.000438, 0.000207])
pt_np_mind0_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
f, ax = plt.subplots()
plt.errorbar(pt_np_quality_center, pt_np_quality_eff, xerr=pt_np_quality_widths/2, yerr=pt_np_quality_err, marker=".", linestyle="", markersize=15,label="Quality")
plt.errorbar(pt_np_minpt_center, pt_np_minpt_eff, xerr=pt_np_minpt_widths/2, yerr=pt_np_minpt_err, marker="v", linestyle="", markersize=8,label="$p_T$ min")
plt.errorbar(pt_np_mind0_center, pt_np_mind0_eff, xerr=pt_np_mind0_widths/2, yerr=pt_np_mind0_err, marker="s", linestyle="", markersize=8,label="$d_0$ min")
plt.ylim(0.0, 1.2)
plt.xlim(0.0,100.0)
plt.xlabel("Track $p_{T}$ [GeV]")
plt.ylabel("Efficiency")
plt.text(0.2,0.9,r"Neutrino Gun",transform=ax.transAxes)
plt.legend()
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU200 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))

# %%
pt_primary_quality_eff = np.array([0.901288, 0.825521, 0.873303, 0.820423, 0.827680, 0.813778, 0.807107, 0.795981, 0.744478, 0.753667, 0.743496, 0.738834, 0.734763, 0.724163, 0.726603, 0.738182, 0.764417, 0.795991, 0.819374, 0.711008])
pt_primary_quality_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_primary_quality_err = np.array([0.019541, 0.019367, 0.015822, 0.016105, 0.013911, 0.012772, 0.012572, 0.011203, 0.010657, 0.009691, 0.008805, 0.008111, 0.007416, 0.006937, 0.006289, 0.005672, 0.005102, 0.004455, 0.004039, 0.003856])
pt_primary_quality_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_primary_minpt_eff = np.array([0.000000, 0.000000, 0.807692, 0.820423, 0.827680, 0.813778, 0.807107, 0.795981, 0.744478, 0.753667, 0.743496, 0.738834, 0.734763, 0.724163, 0.726603, 0.738182, 0.764417, 0.795991, 0.819374, 0.711008])
pt_primary_minpt_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_primary_minpt_err = np.array([0.000000, 0.000000, 0.018746, 0.016105, 0.013911, 0.012772, 0.012572, 0.011203, 0.010657, 0.009691, 0.008805, 0.008111, 0.007416, 0.006937, 0.006289, 0.005672, 0.005102, 0.004455, 0.004039, 0.003856])
pt_primary_minpt_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
pt_primary_mind0_eff = np.array([0.000000, 0.000000, 0.791855, 0.799296, 0.814111, 0.800861, 0.784772, 0.785162, 0.728358, 0.743045, 0.735366, 0.730992, 0.726580, 0.712599, 0.714257, 0.726864, 0.750976, 0.781567, 0.804276, 0.699428])
pt_primary_mind0_widths = np.array([0.432084, 0.525432, 0.638947, 0.776985, 0.944848, 1.148975, 1.397199, 1.699055, 2.066119, 2.512490, 3.055293, 3.715364, 4.518034, 5.494123, 6.681076, 8.124474, 9.879707, 12.014114, 14.609688, 17.765961])
pt_primary_mind0_err = np.array([0.000000, 0.000000, 0.019311, 0.016806, 0.014330, 0.013102, 0.013095, 0.011417, 0.010868, 0.009827, 0.008894, 0.008188, 0.007487, 0.007024, 0.006375, 0.005748, 0.005199, 0.004568, 0.004165, 0.003901])
pt_primary_mind0_center = np.array([2.216042, 2.694799, 3.276989, 3.984955, 4.845872, 5.892783, 7.165870, 8.713998, 10.596585, 12.885890, 15.669781, 19.055110, 23.171809, 28.177888, 34.265488, 41.668262, 50.670353, 61.617264, 74.929165, 91.116989])

# %%
f, ax = plt.subplots()
plt.errorbar(pt_primary_quality_center, pt_primary_quality_eff, xerr=pt_primary_quality_widths/2, yerr=pt_primary_quality_err, marker=".", linestyle="", markersize=15,label="Quality")
plt.errorbar(pt_primary_minpt_center, pt_primary_minpt_eff, xerr=pt_primary_minpt_widths/2, yerr=pt_primary_minpt_err, marker="v", linestyle="", markersize=8,label="$p_T$ min")
plt.errorbar(pt_primary_mind0_center, pt_primary_mind0_eff, xerr=pt_primary_mind0_widths/2, yerr=pt_primary_mind0_err, marker="s", linestyle="", markersize=8,label="$d_0$ min")
plt.ylim(0.01, 1.2)
plt.xlim(0.0,100.0)
plt.xlabel("Track $p_{T}$ [GeV]")
plt.ylabel("Efficiency")
plt.text(0.2,0.9,r"Displaced Muon",transform=ax.transAxes)
plt.legend()
hep.style.use("CMS")
hep.cms.label("Phase-2 Preliminary",rlabel="PU0 (14TeV)",fontsize=16)
# Out:
# (exptext: Custom Text(0.0, 1, 'CMS'),
#  expsuffix: Custom Text(0.0, 1.005, 'Simulation Phase-2 Preliminary'))
